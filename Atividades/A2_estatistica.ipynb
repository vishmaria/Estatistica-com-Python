# %% [markdown]
# # A2 INE5405 - Probabilidade e Estatística
# ## Teste de Hipóteses com Dados da COVID-19 no Brasil: 2020 vs. 2024
# - (a) Escolher um tema de sua área, ou de sua preferência (é recomendado manter o tema utilizado
# no trabalho 1 para facilitar o desenvolvimento das atividades).
# - (b) Selecionar, no mínimo, quatro variáveis de interesse, seguindo as mesmas recomendações do
# trabalho 1, sendo possível manter as variáveis já apresentadas.
# - (c) Fazer uma breve descrição dos dados, calculando estatísticas descritivas (utilizar estimativas
# pontuais e intervalares especialmente para média e proporção, quando for o caso).
# - (d) Levantar pelo menos duas hipóteses envolvendo os dados em análise.
# - (e) Construir os testes de hipóteses e executá-los com base nos dados, discutindo os resultados.
# - (f) Apresentar as conclusões com base nas estatísticas descritivas e testes estatísticos realizados

# %%
# Importar bibliotecas necessárias
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sidetable as stb

# Configurar pandas
pd.set_option('display.max_rows', 100)

# %%
# Carregar dados do exercício anterior 
df = pd.read_parquet('data/a1_dados_covid.parquet')
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2996660 entries, 4551 to 427043
# Data columns (total 10 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   data               datetime64[ns]
#  1   regiao             object
#  2   estado             object
#  3   municipio          object
#  4   populacaoTCU2019   float64
#  5   obitosAcumulado    int64
#  6   obitosNovos        int64
#  7   ano                int32
#  8   mes                object
#  9   percentual_obitos  float64
# dtypes: datetime64[ns](1), float64(2), int32(1), int64(2), object(4)
# memory usage: 240.1+ MB

# %% [markdown]
# ## Variáveis escolhidas:
# - data (para ordenação)
# - regiao
# - estado
# - municipio
# - populacaoTCU
# - obitosAcumulado
# - obitosNovos
# - ano (para comparação)
# - percentual_obitos

# %% [markdown]
# ## Estatísticas descritivas

# %%
df.stb.missing(style=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_06b5d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_06b5d_level0_col0" class="col_heading level0 col0" >missing</th>
#       <th id="T_06b5d_level0_col1" class="col_heading level0 col1" >total</th>
#       <th id="T_06b5d_level0_col2" class="col_heading level0 col2" >percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_06b5d_level0_row0" class="row_heading level0 row0" >data</th>
#       <td id="T_06b5d_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_06b5d_row0_col1" class="data row0 col1" >2,996,660</td>
#       <td id="T_06b5d_row0_col2" class="data row0 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_06b5d_level0_row1" class="row_heading level0 row1" >regiao</th>
#       <td id="T_06b5d_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_06b5d_row1_col1" class="data row1 col1" >2,996,660</td>
#       <td id="T_06b5d_row1_col2" class="data row1 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_06b5d_level0_row2" class="row_heading level0 row2" >estado</th>
#       <td id="T_06b5d_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_06b5d_row2_col1" class="data row2 col1" >2,996,660</td>
#       <td id="T_06b5d_row2_col2" class="data row2 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_06b5d_level0_row3" class="row_heading level0 row3" >municipio</th>
#       <td id="T_06b5d_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_06b5d_row3_col1" class="data row3 col1" >2,996,660</td>
#       <td id="T_06b5d_row3_col2" class="data row3 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_06b5d_level0_row4" class="row_heading level0 row4" >populacaoTCU2019</th>
#       <td id="T_06b5d_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_06b5d_row4_col1" class="data row4 col1" >2,996,660</td>
#       <td id="T_06b5d_row4_col2" class="data row4 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_06b5d_level0_row5" class="row_heading level0 row5" >obitosAcumulado</th>
#       <td id="T_06b5d_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_06b5d_row5_col1" class="data row5 col1" >2,996,660</td>
#       <td id="T_06b5d_row5_col2" class="data row5 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_06b5d_level0_row6" class="row_heading level0 row6" >obitosNovos</th>
#       <td id="T_06b5d_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_06b5d_row6_col1" class="data row6 col1" >2,996,660</td>
#       <td id="T_06b5d_row6_col2" class="data row6 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_06b5d_level0_row7" class="row_heading level0 row7" >ano</th>
#       <td id="T_06b5d_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_06b5d_row7_col1" class="data row7 col1" >2,996,660</td>
#       <td id="T_06b5d_row7_col2" class="data row7 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_06b5d_level0_row8" class="row_heading level0 row8" >mes</th>
#       <td id="T_06b5d_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_06b5d_row8_col1" class="data row8 col1" >2,996,660</td>
#       <td id="T_06b5d_row8_col2" class="data row8 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_06b5d_level0_row9" class="row_heading level0 row9" >percentual_obitos</th>
#       <td id="T_06b5d_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_06b5d_row9_col1" class="data row9 col1" >2,996,660</td>
#       <td id="T_06b5d_row9_col2" class="data row9 col2" >0.00%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### tratamento de distância interquartílica para gráficos

# %%
q1 = df['obitosAcumulado'].quantile(0.25)
q3 = df['obitosAcumulado'].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - 1.5*iqr
upper_bound = q3 + 1.5*iqr
df_plot_acc = df[(df['obitosAcumulado'] > lower_bound) & (df['obitosAcumulado'] < upper_bound)]

# %%
df[['obitosAcumulado','obitosNovos','percentual_obitos']].describe()
# Out:
#        obitosAcumulado   obitosNovos  percentual_obitos
# count     2.996660e+06  2.996660e+06       2.996660e+06
# mean      7.042710e+01  6.648035e-02       1.430992e-01
# std       6.687656e+02  7.655450e+01       3.238256e-01
# min       0.000000e+00 -4.567100e+04       0.000000e+00
# 25%       1.000000e+00  0.000000e+00       7.633711e-03
# 50%       8.000000e+00  0.000000e+00       7.609696e-02
# 75%       3.100000e+01  0.000000e+00       2.393322e-01
# max       4.602400e+04  4.567100e+04       1.283539e+02

# %%
df[df['ano'] == 2020][['obitosAcumulado','obitosNovos','percentual_obitos']].describe()
# Out:
#        obitosAcumulado   obitosNovos  percentual_obitos
# count     1.559600e+06  1.559600e+06       1.559600e+06
# mean      1.776725e+01  1.248089e-01       2.522536e-02
# std       2.168569e+02  7.231061e+01       3.967055e-02
# min       0.000000e+00 -4.095300e+04       0.000000e+00
# 25%       0.000000e+00  0.000000e+00       0.000000e+00
# 50%       1.000000e+00  0.000000e+00       9.652510e-03
# 75%       6.000000e+00  0.000000e+00       3.887475e-02
# max       4.585400e+04  4.118000e+04       1.508496e+01

# %%
df[df['ano'] == 2024][['obitosAcumulado','obitosNovos','percentual_obitos']].describe()
# Out:
#        obitosAcumulado   obitosNovos  percentual_obitos
# count     1.437060e+06  1.437060e+06       1.437060e+06
# mean      1.275773e+02  3.178016e-03       2.710243e-01
# std       9.355853e+02  8.090876e+01       4.307158e-01
# min       0.000000e+00 -4.567100e+04       0.000000e+00
# 25%       1.200000e+01  0.000000e+00       1.619433e-01
# 50%       2.600000e+01  0.000000e+00       2.450980e-01
# 75%       6.400000e+01  0.000000e+00       3.519697e-01
# max       4.602400e+04  4.567100e+04       1.283539e+02

# %%
# Agrupar por municipio e selecionar os top 10
top_mun_2020 = df[df['ano'] == 2020].groupby('municipio').agg({'percentual_obitos':'sum'}).nlargest(10,'percentual_obitos').reset_index()
top_mun_2020
# Out:
#               municipio  percentual_obitos
# 0          Areia Branca          55.027072
# 1                 Belém          53.057458
# 2         São Francisco          50.038369
# 3               Charrua          49.862763
# 4                Itambé          49.186588
# 5           Água Branca          48.132930
# 6        Gastão Vidigal          48.128120
# 7              Sapucaia          41.578290
# 8  Pimenteiras do Oeste          40.986630
# 9    Presidente Kennedy          38.541767

# %%
# óbitos por municipio em 2024
# Agrupar por municipio e selecionar os top 10
top_mun_2024 = df[df['data'] == '2024-09-14'].groupby('municipio').agg({'percentual_obitos':'max'}).nlargest(10,'percentual_obitos').reset_index()
top_mun_2024
# Out:
#              municipio  percentual_obitos
# 0   Santa Rita d'Oeste           2.001601
# 1     Estrela do Norte           1.482285
# 2  Santa Clara d'Oeste           1.229314
# 3           Embu-Guaçu           1.116956
# 4            Meridiano           1.094891
# 5               Parisi           0.925497
# 6        Campos Verdes           0.887436
# 7               Pirapó           0.868056
# 8               Itaúba           0.867964
# 9            Macedônia           0.865333

# %% [markdown]
# ### Tabelas de frequência

# %%
df.stb.freq(['regiao'], style=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_fbde1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fbde1_level0_col0" class="col_heading level0 col0" >regiao</th>
#       <th id="T_fbde1_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_fbde1_level0_col2" class="col_heading level0 col2" >percent</th>
#       <th id="T_fbde1_level0_col3" class="col_heading level0 col3" >cumulative_count</th>
#       <th id="T_fbde1_level0_col4" class="col_heading level0 col4" >cumulative_percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fbde1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fbde1_row0_col0" class="data row0 col0" >Nordeste</td>
#       <td id="T_fbde1_row0_col1" class="data row0 col1" >965,172</td>
#       <td id="T_fbde1_row0_col2" class="data row0 col2" >32.21%</td>
#       <td id="T_fbde1_row0_col3" class="data row0 col3" >965,172</td>
#       <td id="T_fbde1_row0_col4" class="data row0 col4" >32.21%</td>
#     </tr>
#     <tr>
#       <th id="T_fbde1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fbde1_row1_col0" class="data row1 col0" >Sudeste</td>
#       <td id="T_fbde1_row1_col1" class="data row1 col1" >897,384</td>
#       <td id="T_fbde1_row1_col2" class="data row1 col2" >29.95%</td>
#       <td id="T_fbde1_row1_col3" class="data row1 col3" >1,862,556</td>
#       <td id="T_fbde1_row1_col4" class="data row1 col4" >62.15%</td>
#     </tr>
#     <tr>
#       <th id="T_fbde1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fbde1_row2_col0" class="data row2 col0" >Sul</td>
#       <td id="T_fbde1_row2_col1" class="data row2 col1" >640,758</td>
#       <td id="T_fbde1_row2_col2" class="data row2 col2" >21.38%</td>
#       <td id="T_fbde1_row2_col3" class="data row2 col3" >2,503,314</td>
#       <td id="T_fbde1_row2_col4" class="data row2 col4" >83.54%</td>
#     </tr>
#     <tr>
#       <th id="T_fbde1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fbde1_row3_col0" class="data row3 col0" >Centro-Oeste</td>
#       <td id="T_fbde1_row3_col1" class="data row3 col1" >251,246</td>
#       <td id="T_fbde1_row3_col2" class="data row3 col2" >8.38%</td>
#       <td id="T_fbde1_row3_col3" class="data row3 col3" >2,754,560</td>
#       <td id="T_fbde1_row3_col4" class="data row3 col4" >91.92%</td>
#     </tr>
#     <tr>
#       <th id="T_fbde1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fbde1_row4_col0" class="data row4 col0" >Norte</td>
#       <td id="T_fbde1_row4_col1" class="data row4 col1" >242,100</td>
#       <td id="T_fbde1_row4_col2" class="data row4 col2" >8.08%</td>
#       <td id="T_fbde1_row4_col3" class="data row4 col3" >2,996,660</td>
#       <td id="T_fbde1_row4_col4" class="data row4 col4" >100.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.stb.freq(['estado'], style=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_25f75">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_25f75_level0_col0" class="col_heading level0 col0" >estado</th>
#       <th id="T_25f75_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_25f75_level0_col2" class="col_heading level0 col2" >percent</th>
#       <th id="T_25f75_level0_col3" class="col_heading level0 col3" >cumulative_count</th>
#       <th id="T_25f75_level0_col4" class="col_heading level0 col4" >cumulative_percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_25f75_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_25f75_row0_col0" class="data row0 col0" >MG</td>
#       <td id="T_25f75_row0_col1" class="data row0 col1" >458,914</td>
#       <td id="T_25f75_row0_col2" class="data row0 col2" >15.31%</td>
#       <td id="T_25f75_row0_col3" class="data row0 col3" >458,914</td>
#       <td id="T_25f75_row0_col4" class="data row0 col4" >15.31%</td>
#     </tr>
#     <tr>
#       <th id="T_25f75_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_25f75_row1_col0" class="data row1 col0" >SP</td>
#       <td id="T_25f75_row1_col1" class="data row1 col1" >347,010</td>
#       <td id="T_25f75_row1_col2" class="data row1 col2" >11.58%</td>
#       <td id="T_25f75_row1_col3" class="data row1 col3" >805,924</td>
#       <td id="T_25f75_row1_col4" class="data row1 col4" >26.89%</td>
#     </tr>
#     <tr>
#       <th id="T_25f75_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_25f75_row2_col0" class="data row2 col0" >RS</td>
#       <td id="T_25f75_row2_col1" class="data row2 col1" >267,386</td>
#       <td id="T_25f75_row2_col2" class="data row2 col2" >8.92%</td>
#       <td id="T_25f75_row2_col3" class="data row2 col3" >1,073,310</td>
#       <td id="T_25f75_row2_col4" class="data row2 col4" >35.82%</td>
#     </tr>
#     <tr>
#       <th id="T_25f75_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_25f75_row3_col0" class="data row3 col0" >BA</td>
#       <td id="T_25f75_row3_col1" class="data row3 col1" >224,346</td>
#       <td id="T_25f75_row3_col2" class="data row3 col2" >7.49%</td>
#       <td id="T_25f75_row3_col3" class="data row3 col3" >1,297,656</td>
#       <td id="T_25f75_row3_col4" class="data row3 col4" >43.30%</td>
#     </tr>
#     <tr>
#       <th id="T_25f75_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_25f75_row4_col0" class="data row4 col0" >PR</td>
#       <td id="T_25f75_row4_col1" class="data row4 col1" >214,662</td>
#       <td id="T_25f75_row4_col2" class="data row4 col2" >7.16%</td>
#       <td id="T_25f75_row4_col3" class="data row4 col3" >1,512,318</td>
#       <td id="T_25f75_row4_col4" class="data row4 col4" >50.47%</td>
#     </tr>
#     <tr>
#       <th id="T_25f75_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_25f75_row5_col0" class="data row5 col0" >SC</td>
#       <td id="T_25f75_row5_col1" class="data row5 col1" >158,710</td>
#       <td id="T_25f75_row5_col2" class="data row5 col2" >5.30%</td>
#       <td id="T_25f75_row5_col3" class="data row5 col3" >1,671,028</td>
#       <td id="T_25f75_row5_col4" class="data row5 col4" >55.76%</td>
#     </tr>
#     <tr>
#       <th id="T_25f75_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_25f75_row6_col0" class="data row6 col0" >GO</td>
#       <td id="T_25f75_row6_col1" class="data row6 col1" >132,348</td>
#       <td id="T_25f75_row6_col2" class="data row6 col2" >4.42%</td>
#       <td id="T_25f75_row6_col3" class="data row6 col3" >1,803,376</td>
#       <td id="T_25f75_row6_col4" class="data row6 col4" >60.18%</td>
#     </tr>
#     <tr>
#       <th id="T_25f75_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_25f75_row7_col0" class="data row7 col0" >PI</td>
#       <td id="T_25f75_row7_col1" class="data row7 col1" >120,512</td>
#       <td id="T_25f75_row7_col2" class="data row7 col2" >4.02%</td>
#       <td id="T_25f75_row7_col3" class="data row7 col3" >1,923,888</td>
#       <td id="T_25f75_row7_col4" class="data row7 col4" >64.20%</td>
#     </tr>
#     <tr>
#       <th id="T_25f75_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_25f75_row8_col0" class="data row8 col0" >PB</td>
#       <td id="T_25f75_row8_col1" class="data row8 col1" >119,974</td>
#       <td id="T_25f75_row8_col2" class="data row8 col2" >4.00%</td>
#       <td id="T_25f75_row8_col3" class="data row8 col3" >2,043,862</td>
#       <td id="T_25f75_row8_col4" class="data row8 col4" >68.20%</td>
#     </tr>
#     <tr>
#       <th id="T_25f75_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_25f75_row9_col0" class="data row9 col0" >MA</td>
#       <td id="T_25f75_row9_col1" class="data row9 col1" >116,746</td>
#       <td id="T_25f75_row9_col2" class="data row9 col2" >3.90%</td>
#       <td id="T_25f75_row9_col3" class="data row9 col3" >2,160,608</td>
#       <td id="T_25f75_row9_col4" class="data row9 col4" >72.10%</td>
#     </tr>
#     <tr>
#       <th id="T_25f75_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_25f75_row10_col0" class="data row10 col0" >PE</td>
#       <td id="T_25f75_row10_col1" class="data row10 col1" >99,530</td>
#       <td id="T_25f75_row10_col2" class="data row10 col2" >3.32%</td>
#       <td id="T_25f75_row10_col3" class="data row10 col3" >2,260,138</td>
#       <td id="T_25f75_row10_col4" class="data row10 col4" >75.42%</td>
#     </tr>
#     <tr>
#       <th id="T_25f75_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_25f75_row11_col0" class="data row11 col0" >CE</td>
#       <td id="T_25f75_row11_col1" class="data row11 col1" >98,992</td>
#       <td id="T_25f75_row11_col2" class="data row11 col2" >3.30%</td>
#       <td id="T_25f75_row11_col3" class="data row11 col3" >2,359,130</td>
#       <td id="T_25f75_row11_col4" class="data row11 col4" >78.73%</td>
#     </tr>
#     <tr>
#       <th id="T_25f75_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_25f75_row12_col0" class="data row12 col0" >RN</td>
#       <td id="T_25f75_row12_col1" class="data row12 col1" >89,846</td>
#       <td id="T_25f75_row12_col2" class="data row12 col2" >3.00%</td>
#       <td id="T_25f75_row12_col3" class="data row12 col3" >2,448,976</td>
#       <td id="T_25f75_row12_col4" class="data row12 col4" >81.72%</td>
#     </tr>
#     <tr>
#       <th id="T_25f75_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_25f75_row13_col0" class="data row13 col0" >PA</td>
#       <td id="T_25f75_row13_col1" class="data row13 col1" >77,472</td>
#       <td id="T_25f75_row13_col2" class="data row13 col2" >2.59%</td>
#       <td id="T_25f75_row13_col3" class="data row13 col3" >2,526,448</td>
#       <td id="T_25f75_row13_col4" class="data row13 col4" >84.31%</td>
#     </tr>
#     <tr>
#       <th id="T_25f75_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_25f75_row14_col0" class="data row14 col0" >MT</td>
#       <td id="T_25f75_row14_col1" class="data row14 col1" >75,858</td>
#       <td id="T_25f75_row14_col2" class="data row14 col2" >2.53%</td>
#       <td id="T_25f75_row14_col3" class="data row14 col3" >2,602,306</td>
#       <td id="T_25f75_row14_col4" class="data row14 col4" >86.84%</td>
#     </tr>
#     <tr>
#       <th id="T_25f75_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_25f75_row15_col0" class="data row15 col0" >TO</td>
#       <td id="T_25f75_row15_col1" class="data row15 col1" >74,782</td>
#       <td id="T_25f75_row15_col2" class="data row15 col2" >2.50%</td>
#       <td id="T_25f75_row15_col3" class="data row15 col3" >2,677,088</td>
#       <td id="T_25f75_row15_col4" class="data row15 col4" >89.34%</td>
#     </tr>
#     <tr>
#       <th id="T_25f75_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_25f75_row16_col0" class="data row16 col0" >AL</td>
#       <td id="T_25f75_row16_col1" class="data row16 col1" >54,876</td>
#       <td id="T_25f75_row16_col2" class="data row16 col2" >1.83%</td>
#       <td id="T_25f75_row16_col3" class="data row16 col3"

# %%
# Tabela de frequência para a variável 'regiao' e total de óbitos
df[df['data'] == '2024-09-14'].stb.freq(['regiao'],value='obitosAcumulado',style=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9506c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9506c_level0_col0" class="col_heading level0 col0" >regiao</th>
#       <th id="T_9506c_level0_col1" class="col_heading level0 col1" >obitosAcumulado</th>
#       <th id="T_9506c_level0_col2" class="col_heading level0 col2" >percent</th>
#       <th id="T_9506c_level0_col3" class="col_heading level0 col3" >cumulative_obitosAcumulado</th>
#       <th id="T_9506c_level0_col4" class="col_heading level0 col4" >cumulative_percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9506c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9506c_row0_col0" class="data row0 col0" >Sudeste</td>
#       <td id="T_9506c_row0_col1" class="data row0 col1" >343,673</td>
#       <td id="T_9506c_row0_col2" class="data row0 col2" >48.25%</td>
#       <td id="T_9506c_row0_col3" class="data row0 col3" >343,673</td>
#       <td id="T_9506c_row0_col4" class="data row0 col4" >48.25%</td>
#     </tr>
#     <tr>
#       <th id="T_9506c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9506c_row1_col0" class="data row1 col0" >Nordeste</td>
#       <td id="T_9506c_row1_col1" class="data row1 col1" >136,564</td>
#       <td id="T_9506c_row1_col2" class="data row1 col2" >19.17%</td>
#       <td id="T_9506c_row1_col3" class="data row1 col3" >480,237</td>
#       <td id="T_9506c_row1_col4" class="data row1 col4" >67.42%</td>
#     </tr>
#     <tr>
#       <th id="T_9506c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9506c_row2_col0" class="data row2 col0" >Sul</td>
#       <td id="T_9506c_row2_col1" class="data row2 col1" >112,836</td>
#       <td id="T_9506c_row2_col2" class="data row2 col2" >15.84%</td>
#       <td id="T_9506c_row2_col3" class="data row2 col3" >593,073</td>
#       <td id="T_9506c_row2_col4" class="data row2 col4" >83.26%</td>
#     </tr>
#     <tr>
#       <th id="T_9506c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9506c_row3_col0" class="data row3 col0" >Centro-Oeste</td>
#       <td id="T_9506c_row3_col1" class="data row3 col1" >67,148</td>
#       <td id="T_9506c_row3_col2" class="data row3 col2" >9.43%</td>
#       <td id="T_9506c_row3_col3" class="data row3 col3" >660,221</td>
#       <td id="T_9506c_row3_col4" class="data row3 col4" >92.69%</td>
#     </tr>
#     <tr>
#       <th id="T_9506c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9506c_row4_col0" class="data row4 col0" >Norte</td>
#       <td id="T_9506c_row4_col1" class="data row4 col1" >52,066</td>
#       <td id="T_9506c_row4_col2" class="data row4 col2" >7.31%</td>
#       <td id="T_9506c_row4_col3" class="data row4 col3" >712,287</td>
#       <td id="T_9506c_row4_col4" class="data row4 col4" >100.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
df[df['data'] == '2024-09-14'].obitosAcumulado.sum()
# Out:
# np.int64(712287)

# %%
# Obitos em 2020 por regiao
df[df['ano'] == 2020].stb.freq(['regiao'], value='obitosNovos',style=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_77aa0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_77aa0_level0_col0" class="col_heading level0 col0" >regiao</th>
#       <th id="T_77aa0_level0_col1" class="col_heading level0 col1" >obitosNovos</th>
#       <th id="T_77aa0_level0_col2" class="col_heading level0 col2" >percent</th>
#       <th id="T_77aa0_level0_col3" class="col_heading level0 col3" >cumulative_obitosNovos</th>
#       <th id="T_77aa0_level0_col4" class="col_heading level0 col4" >cumulative_percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_77aa0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_77aa0_row0_col0" class="data row0 col0" >Sudeste</td>
#       <td id="T_77aa0_row0_col1" class="data row0 col1" >89,072</td>
#       <td id="T_77aa0_row0_col2" class="data row0 col2" >45.76%</td>
#       <td id="T_77aa0_row0_col3" class="data row0 col3" >89,072</td>
#       <td id="T_77aa0_row0_col4" class="data row0 col4" >45.76%</td>
#     </tr>
#     <tr>
#       <th id="T_77aa0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_77aa0_row1_col0" class="data row1 col0" >Nordeste</td>
#       <td id="T_77aa0_row1_col1" class="data row1 col1" >47,676</td>
#       <td id="T_77aa0_row1_col2" class="data row1 col2" >24.49%</td>
#       <td id="T_77aa0_row1_col3" class="data row1 col3" >136,748</td>
#       <td id="T_77aa0_row1_col4" class="data row1 col4" >70.25%</td>
#     </tr>
#     <tr>
#       <th id="T_77aa0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_77aa0_row2_col0" class="data row2 col0" >Sul</td>
#       <td id="T_77aa0_row2_col1" class="data row2 col1" >22,037</td>
#       <td id="T_77aa0_row2_col2" class="data row2 col2" >11.32%</td>
#       <td id="T_77aa0_row2_col3" class="data row2 col3" >158,785</td>
#       <td id="T_77aa0_row2_col4" class="data row2 col4" >81.57%</td>
#     </tr>
#     <tr>
#       <th id="T_77aa0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_77aa0_row3_col0" class="data row3 col0" >Norte</td>
#       <td id="T_77aa0_row3_col1" class="data row3 col1" >18,019</td>
#       <td id="T_77aa0_row3_col2" class="data row3 col2" >9.26%</td>
#       <td id="T_77aa0_row3_col3" class="data row3 col3" >176,804</td>
#       <td id="T_77aa0_row3_col4" class="data row3 col4" >90.83%</td>
#     </tr>
#     <tr>
#       <th id="T_77aa0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_77aa0_row4_col0" class="data row4 col0" >Centro-Oeste</td>
#       <td id="T_77aa0_row4_col1" class="data row4 col1" >17,848</td>
#       <td id="T_77aa0_row4_col2" class="data row4 col2" >9.17%</td>
#       <td id="T_77aa0_row4_col3" class="data row4 col3" >194,652</td>
#       <td id="T_77aa0_row4_col4" class="data row4 col4" >100.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Obitos em 2024 por regiao
df[df['ano'] == 2024].stb.freq(['regiao'], value='obitosNovos',style=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_8f4a3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8f4a3_level0_col0" class="col_heading level0 col0" >regiao</th>
#       <th id="T_8f4a3_level0_col1" class="col_heading level0 col1" >obitosNovos</th>
#       <th id="T_8f4a3_level0_col2" class="col_heading level0 col2" >percent</th>
#       <th id="T_8f4a3_level0_col3" class="col_heading level0 col3" >cumulative_obitosNovos</th>
#       <th id="T_8f4a3_level0_col4" class="col_heading level0 col4" >cumulative_percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8f4a3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8f4a3_row0_col0" class="data row0 col0" >Sudeste</td>
#       <td id="T_8f4a3_row0_col1" class="data row0 col1" >2,689</td>
#       <td id="T_8f4a3_row0_col2" class="data row0 col2" >58.88%</td>
#       <td id="T_8f4a3_row0_col3" class="data row0 col3" >2,689</td>
#       <td id="T_8f4a3_row0_col4" class="data row0 col4" >58.88%</td>
#     </tr>
#     <tr>
#       <th id="T_8f4a3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8f4a3_row1_col0" class="data row1 col0" >Sul</td>
#       <td id="T_8f4a3_row1_col1" class="data row1 col1" >688</td>
#       <td id="T_8f4a3_row1_col2" class="data row1 col2" >15.06%</td>
#       <td id="T_8f4a3_row1_col3" class="data row1 col3" >3,377</td>
#       <td id="T_8f4a3_row1_col4" class="data row1 col4" >73.94%</td>
#     </tr>
#     <tr>
#       <th id="T_8f4a3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8f4a3_row2_col0" class="data row2 col0" >Nordeste</td>
#       <td id="T_8f4a3_row2_col1" class="data row2 col1" >498</td>
#       <td id="T_8f4a3_row2_col2" class="data row2 col2" >10.90%</td>
#       <td id="T_8f4a3_row2_col3" class="data row2 col3" >3,875</td>
#       <td id="T_8f4a3_row2_col4" class="data row2 col4" >84.85%</td>
#     </tr>
#     <tr>
#       <th id="T_8f4a3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8f4a3_row3_col0" class="data row3 col0" >Centro-Oeste</td>
#       <td id="T_8f4a3_row3_col1" class="data row3 col1" >428</td>
#       <td id="T_8f4a3_row3_col2" class="data row3 col2" >9.37%</td>
#       <td id="T_8f4a3_row3_col3" class="data row3 col3" >4,303</td>
#       <td id="T_8f4a3_row3_col4" class="data row3 col4" >94.22%</td>
#     </tr>
#     <tr>
#       <th id="T_8f4a3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8f4a3_row4_col0" class="data row4 col0" >Norte</td>
#       <td id="T_8f4a3_row4_col1" class="data row4 col1" >264</td>
#       <td id="T_8f4a3_row4_col2" class="data row4 col2" >5.78%</td>
#       <td id="T_8f4a3_row4_col3" class="data row4 col3" >4,567</td>
#       <td id="T_8f4a3_row4_col4" class="data row4 col4" >100.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
df[df['ano'] == 2020].obitosNovos.sum()
# Out:
# np.int64(194652)

# %%
df[df['ano'] == 2024].obitosNovos.sum()
# Out:
# np.int64(4567)

# %%
# Total de obitos por estado
df[df['data'] == '2024-09-14'].stb.freq(['estado'],value='obitosAcumulado',style=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_8a9b1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8a9b1_level0_col0" class="col_heading level0 col0" >estado</th>
#       <th id="T_8a9b1_level0_col1" class="col_heading level0 col1" >obitosAcumulado</th>
#       <th id="T_8a9b1_level0_col2" class="col_heading level0 col2" >percent</th>
#       <th id="T_8a9b1_level0_col3" class="col_heading level0 col3" >cumulative_obitosAcumulado</th>
#       <th id="T_8a9b1_level0_col4" class="col_heading level0 col4" >cumulative_percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a9b1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8a9b1_row0_col0" class="data row0 col0" >SP</td>
#       <td id="T_8a9b1_row0_col1" class="data row0 col1" >183,849</td>
#       <td id="T_8a9b1_row0_col2" class="data row0 col2" >25.81%</td>
#       <td id="T_8a9b1_row0_col3" class="data row0 col3" >183,849</td>
#       <td id="T_8a9b1_row0_col4" class="data row0 col4" >25.81%</td>
#     </tr>
#     <tr>
#       <th id="T_8a9b1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8a9b1_row1_col0" class="data row1 col0" >RJ</td>
#       <td id="T_8a9b1_row1_col1" class="data row1 col1" >78,198</td>
#       <td id="T_8a9b1_row1_col2" class="data row1 col2" >10.98%</td>
#       <td id="T_8a9b1_row1_col3" class="data row1 col3" >262,047</td>
#       <td id="T_8a9b1_row1_col4" class="data row1 col4" >36.79%</td>
#     </tr>
#     <tr>
#       <th id="T_8a9b1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8a9b1_row2_col0" class="data row2 col0" >MG</td>
#       <td id="T_8a9b1_row2_col1" class="data row2 col1" >66,698</td>
#       <td id="T_8a9b1_row2_col2" class="data row2 col2" >9.36%</td>
#       <td id="T_8a9b1_row2_col3" class="data row2 col3" >328,745</td>
#       <td id="T_8a9b1_row2_col4" class="data row2 col4" >46.15%</td>
#     </tr>
#     <tr>
#       <th id="T_8a9b1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8a9b1_row3_col0" class="data row3 col0" >PR</td>
#       <td id="T_8a9b1_row3_col1" class="data row3 col1" >46,710</td>
#       <td id="T_8a9b1_row3_col2" class="data row3 col2" >6.56%</td>
#       <td id="T_8a9b1_row3_col3" class="data row3 col3" >375,455</td>
#       <td id="T_8a9b1_row3_col4" class="data row3 col4" >52.71%</td>
#     </tr>
#     <tr>
#       <th id="T_8a9b1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8a9b1_row4_col0" class="data row4 col0" >RS</td>
#       <td id="T_8a9b1_row4_col1" class="data row4 col1" >43,007</td>
#       <td id="T_8a9b1_row4_col2" class="data row4 col2" >6.04%</td>
#       <td id="T_8a9b1_row4_col3" class="data row4 col3" >418,462</td>
#       <td id="T_8a9b1_row4_col4" class="data row4 col4" >58.75%</td>
#     </tr>
#     <tr>
#       <th id="T_8a9b1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8a9b1_row5_col0" class="data row5 col0" >BA</td>
#       <td id="T_8a9b1_row5_col1" class="data row5 col1" >31,656</td>
#       <td id="T_8a9b1_row5_col2" class="data row5 col2" >4.44%</td>
#       <td id="T_8a9b1_row5_col3" class="data row5 col3" >450,118</td>
#       <td id="T_8a9b1_row5_col4" class="data row5 col4" >63.19%</td>
#     </tr>
#     <tr>
#       <th id="T_8a9b1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8a9b1_row6_col0" class="data row6 col0" >GO</td>
#       <td id="T_8a9b1_row6_col1" class="data row6 col1" >28,619</td>
#       <td id="T_8a9b1_row6_col2" class="data row6 col2" >4.02%</td>
#       <td id="T_8a9b1_row6_col3" class="data row6 col3" >478,737</td>
#       <td id="T_8a9b1_row6_col4" class="data row6 col4" >67.21%</td>
#     </tr>
#     <tr>
#       <th id="T_8a9b1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8a9b1_row7_col0" class="data row7 col0" >CE</td>
#       <td id="T_8a9b1_row7_col1" class="data row7 col1" >28,215</td>
#       <td id="T_8a9b1_row7_col2" class="data row7 col2" >3.96%</td>
#       <td id="T_8a9b1_row7_col3" class="data row7 col3" >506,952</td>
#       <td id="T_8a9b1_row7_col4" class="data row7 col4" >71.17%</td>
#     </tr>
#     <tr>
#       <th id="T_8a9b1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8a9b1_row8_col0" class="data row8 col0" >PE</td>
#       <td id="T_8a9b1_row8_col1" class="data row8 col1" >23,240</td>
#       <td id="T_8a9b1_row8_col2" class="data row8 col2" >3.26%</td>
#       <td id="T_8a9b1_row8_col3" class="data row8 col3" >530,192</td>
#       <td id="T_8a9b1_row8_col4" class="data row8 col4" >74.44%</td>
#     </tr>
#     <tr>
#       <th id="T_8a9b1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8a9b1_row9_col0" class="data row9 col0" >SC</td>
#       <td id="T_8a9b1_row9_col1" class="data row9 col1" >23,119</td>
#       <td id="T_8a9b1_row9_col2" class="data row9 col2" >3.25%</td>
#       <td id="T_8a9b1_row9_col3" class="data row9 col3" >553,311</td>
#       <td id="T_8a9b1_row9_col4" class="data row9 col4" >77.68%</td>
#     </tr>
#     <tr>
#       <th id="T_8a9b1_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_8a9b1_row10_col0" class="data row10 col0" >PA</td>
#       <td id="T_8a9b1_row10_col1" class="data row10 col1" >19,289</td>
#       <td id="T_8a9b1_row10_col2" class="data row10 col2" >2.71%</td>
#       <td id="T_8a9b1_row10_col3" class="data row10 col3" >572,600</td>
#       <td id="T_8a9b1_row10_col4" class="data row10 col4" >80.39%</td>
#     </tr>
#     <tr>
#       <th id="T_8a9b1_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_8a9b1_row11_col0" class="data row11 col0" >MT</td>
#       <td id="T_8a9b1_row11_col1" class="data row11 col1" >15,241</td>
#       <td id="T_8a9b1_row11_col2" class="data row11 col2" >2.14%</td>
#       <td id="T_8a9b1_row11_col3" class="data row11 col3" >587,841</td>
#       <td id="T_8a9b1_row11_col4" class="data row11 col4" >82.53%</td>
#     </tr>
#     <tr>
#       <th id="T_8a9b1_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_8a9b1_row12_col0" class="data row12 col0" >ES</td>
#       <td id="T_8a9b1_row12_col1" class="data row12 col1" >14,928</td>
#       <td id="T_8a9b1_row12_col2" class="data row12 col2" >2.10%</td>
#       <td id="T_8a9b1_row12_col3" class="data row12 col3" >602,769</td>
#       <td id="T_8a9b1_row12_col4" class="data row12 col4" >84.62%</td>
#     </tr>
#     <tr>
#       <th id="T_8a9b1_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_8a9b1_row13_col0" class="data row13 col0" >AM</td>
#       <td id="T_8a9b1_row13_col1" class="data row13 col1" >14,514</td>
#       <td id="T_8a9b1_row13_col2" class="data row13 col2" >2.04%</td>
#       <td id="T_8a9b1_row13_col3" class="data row13 col3" >617,283</td>
#       <td id="T_8a9b1_row13_col4" class="data row13 col4" >86.66%</td>
#     </tr>
#     <tr>
#       <th id="T_8a9b1_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_8a9b1_row14_col0" class="data row14 col0" >DF</td>
#       <td id="T_8a9b1_row14_col1" class="data row14 col1" >12,014</td>
#       <td id="T_8a9b1_row14_col2" class="data row14 col2" >1.69%</td>
#       <td id="T_8a9b1_row14_col3" class="data row14 col3" >629,297</td>
#       <td id="T_8a9b1_row14_col4" class="data row14 col4" >88.35%</td>
#     </tr>
#     <tr>
#       <th id="T_8a9b1_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_8a9b1_row15_col0" class="data row15 col0" >MS</td>
#       <td id="T_8a9b1_row15_col1" class="data row15 col1" >11,274</td>
#       <td id="T_8a9b1_row15_col2" class="data row15 col2" >1.58%</td>
#       <td id="T_8a9b1_row15_col3" class="data row15 col3" >640,571</td>
#       <td id="T_8a9b1_row15_col4" class="data row15 col4" >89.93%</td>
#     </tr>
#     <tr>
#       <th id="T_8a9b1_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_8a9b1_row16_col0" class="data row16 col0" >MA</td>
#       <td id="T_8a9b1_row16_col1" class="data row16 col1" >11,103</td>
#       <td id="T_8a9b1_row16_col2" class="data row16 col2" >1.56%</td>
#       <td id="T_8a9b1_row16_col3" class="data row16 col3" >651,674</td>

# %%
# Total de obitos por estado em 2020
df[df['ano'] == 2020].stb.freq(['estado'],value='obitosNovos',style=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_20d4c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_20d4c_level0_col0" class="col_heading level0 col0" >estado</th>
#       <th id="T_20d4c_level0_col1" class="col_heading level0 col1" >obitosNovos</th>
#       <th id="T_20d4c_level0_col2" class="col_heading level0 col2" >percent</th>
#       <th id="T_20d4c_level0_col3" class="col_heading level0 col3" >cumulative_obitosNovos</th>
#       <th id="T_20d4c_level0_col4" class="col_heading level0 col4" >cumulative_percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_20d4c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_20d4c_row0_col0" class="data row0 col0" >SP</td>
#       <td id="T_20d4c_row0_col1" class="data row0 col1" >46,717</td>
#       <td id="T_20d4c_row0_col2" class="data row0 col2" >24.00%</td>
#       <td id="T_20d4c_row0_col3" class="data row0 col3" >46,717</td>
#       <td id="T_20d4c_row0_col4" class="data row0 col4" >24.00%</td>
#     </tr>
#     <tr>
#       <th id="T_20d4c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_20d4c_row1_col0" class="data row1 col0" >RJ</td>
#       <td id="T_20d4c_row1_col1" class="data row1 col1" >25,530</td>
#       <td id="T_20d4c_row1_col2" class="data row1 col2" >13.12%</td>
#       <td id="T_20d4c_row1_col3" class="data row1 col3" >72,247</td>
#       <td id="T_20d4c_row1_col4" class="data row1 col4" >37.12%</td>
#     </tr>
#     <tr>
#       <th id="T_20d4c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_20d4c_row2_col0" class="data row2 col0" >MG</td>
#       <td id="T_20d4c_row2_col1" class="data row2 col1" >11,804</td>
#       <td id="T_20d4c_row2_col2" class="data row2 col2" >6.06%</td>
#       <td id="T_20d4c_row2_col3" class="data row2 col3" >84,051</td>
#       <td id="T_20d4c_row2_col4" class="data row2 col4" >43.18%</td>
#     </tr>
#     <tr>
#       <th id="T_20d4c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_20d4c_row3_col0" class="data row3 col0" >CE</td>
#       <td id="T_20d4c_row3_col1" class="data row3 col1" >9,990</td>
#       <td id="T_20d4c_row3_col2" class="data row3 col2" >5.13%</td>
#       <td id="T_20d4c_row3_col3" class="data row3 col3" >94,041</td>
#       <td id="T_20d4c_row3_col4" class="data row3 col4" >48.31%</td>
#     </tr>
#     <tr>
#       <th id="T_20d4c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_20d4c_row4_col0" class="data row4 col0" >PE</td>
#       <td id="T_20d4c_row4_col1" class="data row4 col1" >9,654</td>
#       <td id="T_20d4c_row4_col2" class="data row4 col2" >4.96%</td>
#       <td id="T_20d4c_row4_col3" class="data row4 col3" >103,695</td>
#       <td id="T_20d4c_row4_col4" class="data row4 col4" >53.27%</td>
#     </tr>
#     <tr>
#       <th id="T_20d4c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_20d4c_row5_col0" class="data row5 col0" >BA</td>
#       <td id="T_20d4c_row5_col1" class="data row5 col1" >9,065</td>
#       <td id="T_20d4c_row5_col2" class="data row5 col2" >4.66%</td>
#       <td id="T_20d4c_row5_col3" class="data row5 col3" >112,760</td>
#       <td id="T_20d4c_row5_col4" class="data row5 col4" >57.93%</td>
#     </tr>
#     <tr>
#       <th id="T_20d4c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_20d4c_row6_col0" class="data row6 col0" >RS</td>
#       <td id="T_20d4c_row6_col1" class="data row6 col1" >8,872</td>
#       <td id="T_20d4c_row6_col2" class="data row6 col2" >4.56%</td>
#       <td id="T_20d4c_row6_col3" class="data row6 col3" >121,632</td>
#       <td id="T_20d4c_row6_col4" class="data row6 col4" >62.49%</td>
#     </tr>
#     <tr>
#       <th id="T_20d4c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_20d4c_row7_col0" class="data row7 col0" >PR</td>
#       <td id="T_20d4c_row7_col1" class="data row7 col1" >7,912</td>
#       <td id="T_20d4c_row7_col2" class="data row7 col2" >4.06%</td>
#       <td id="T_20d4c_row7_col3" class="data row7 col3" >129,544</td>
#       <td id="T_20d4c_row7_col4" class="data row7 col4" >66.55%</td>
#     </tr>
#     <tr>
#       <th id="T_20d4c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_20d4c_row8_col0" class="data row8 col0" >PA</td>
#       <td id="T_20d4c_row8_col1" class="data row8 col1" >7,188</td>
#       <td id="T_20d4c_row8_col2" class="data row8 col2" >3.69%</td>
#       <td id="T_20d4c_row8_col3" class="data row8 col3" >136,732</td>
#       <td id="T_20d4c_row8_col4" class="data row8 col4" >70.24%</td>
#     </tr>
#     <tr>
#       <th id="T_20d4c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_20d4c_row9_col0" class="data row9 col0" >GO</td>
#       <td id="T_20d4c_row9_col1" class="data row9 col1" >6,805</td>
#       <td id="T_20d4c_row9_col2" class="data row9 col2" >3.50%</td>
#       <td id="T_20d4c_row9_col3" class="data row9 col3" >143,537</td>
#       <td id="T_20d4c_row9_col4" class="data row9 col4" >73.74%</td>
#     </tr>
#     <tr>
#       <th id="T_20d4c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_20d4c_row10_col0" class="data row10 col0" >AM</td>
#       <td id="T_20d4c_row10_col1" class="data row10 col1" >5,285</td>
#       <td id="T_20d4c_row10_col2" class="data row10 col2" >2.72%</td>
#       <td id="T_20d4c_row10_col3" class="data row10 col3" >148,822</td>
#       <td id="T_20d4c_row10_col4" class="data row10 col4" >76.46%</td>
#     </tr>
#     <tr>
#       <th id="T_20d4c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_20d4c_row11_col0" class="data row11 col0" >SC</td>
#       <td id="T_20d4c_row11_col1" class="data row11 col1" >5,253</td>
#       <td id="T_20d4c_row11_col2" class="data row11 col2" >2.70%</td>
#       <td id="T_20d4c_row11_col3" class="data row11 col3" >154,075</td>
#       <td id="T_20d4c_row11_col4" class="data row11 col4" >79.15%</td>
#     </tr>
#     <tr>
#       <th id="T_20d4c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_20d4c_row12_col0" class="data row12 col0" >ES</td>
#       <td id="T_20d4c_row12_col1" class="data row12 col1" >5,021</td>
#       <td id="T_20d4c_row12_col2" class="data row12 col2" >2.58%</td>
#       <td id="T_20d4c_row12_col3" class="data row12 col3" >159,096</td>
#       <td id="T_20d4c_row12_col4" class="data row12 col4" >81.73%</td>
#     </tr>
#     <tr>
#       <th id="T_20d4c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_20d4c_row13_col0" class="data row13 col0" >MA</td>
#       <td id="T_20d4c_row13_col1" class="data row13 col1" >4,500</td>
#       <td id="T_20d4c_row13_col2" class="data row13 col2" >2.31%</td>
#       <td id="T_20d4c_row13_col3" class="data row13 col3" >163,596</td>
#       <td id="T_20d4c_row13_col4" class="data row13 col4" >84.05%</td>
#     </tr>
#     <tr>
#       <th id="T_20d4c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_20d4c_row14_col0" class="data row14 col0" >MT</td>
#       <td id="T_20d4c_row14_col1" class="data row14 col1" >4,455</td>
#       <td id="T_20d4c_row14_col2" class="data row14 col2" >2.29%</td>
#       <td id="T_20d4c_row14_col3" class="data row14 col3" >168,051</td>
#       <td id="T_20d4c_row14_col4" class="data row14 col4" >86.33%</td>
#     </tr>
#     <tr>
#       <th id="T_20d4c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_20d4c_row15_col0" class="data row15 col0" >DF</td>
#       <td id="T_20d4c_row15_col1" class="data row15 col1" >4,259</td>
#       <td id="T_20d4c_row15_col2" class="data row15 col2" >2.19%</td>
#       <td id="T_20d4c_row15_col3" class="data row15 col3" >172,310</td>
#       <td id="T_20d4c_row15_col4" class="data row15 col4" >88.52%</td>
#     </tr>
#     <tr>
#       <th id="T_20d4c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_20d4c_row16_col0" class="data row16 col0" >PB</td>
#       <td id="T_20d4c_row16_col1" class="data row16 col1" >3,672</td>
#       <td id="T_20d4c_row16_col2" class="data row16 col2" >1.89%</td>
#       <td id="T_20d4c_row16_col3" class="data row16 col3" >175,982</td>
#       <td id="T_20d4c_row16_c

# %%
# Total de obitos por estado em 2024
df[df['ano'] == 2024].stb.freq(['estado'],value='obitosNovos',style=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_008c6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_008c6_level0_col0" class="col_heading level0 col0" >estado</th>
#       <th id="T_008c6_level0_col1" class="col_heading level0 col1" >obitosNovos</th>
#       <th id="T_008c6_level0_col2" class="col_heading level0 col2" >percent</th>
#       <th id="T_008c6_level0_col3" class="col_heading level0 col3" >cumulative_obitosNovos</th>
#       <th id="T_008c6_level0_col4" class="col_heading level0 col4" >cumulative_percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_008c6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_008c6_row0_col0" class="data row0 col0" >SP</td>
#       <td id="T_008c6_row0_col1" class="data row0 col1" >1,595</td>
#       <td id="T_008c6_row0_col2" class="data row0 col2" >34.92%</td>
#       <td id="T_008c6_row0_col3" class="data row0 col3" >1,595</td>
#       <td id="T_008c6_row0_col4" class="data row0 col4" >34.92%</td>
#     </tr>
#     <tr>
#       <th id="T_008c6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_008c6_row1_col0" class="data row1 col0" >MG</td>
#       <td id="T_008c6_row1_col1" class="data row1 col1" >602</td>
#       <td id="T_008c6_row1_col2" class="data row1 col2" >13.18%</td>
#       <td id="T_008c6_row1_col3" class="data row1 col3" >2,197</td>
#       <td id="T_008c6_row1_col4" class="data row1 col4" >48.11%</td>
#     </tr>
#     <tr>
#       <th id="T_008c6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_008c6_row2_col0" class="data row2 col0" >RJ</td>
#       <td id="T_008c6_row2_col1" class="data row2 col1" >433</td>
#       <td id="T_008c6_row2_col2" class="data row2 col2" >9.48%</td>
#       <td id="T_008c6_row2_col3" class="data row2 col3" >2,630</td>
#       <td id="T_008c6_row2_col4" class="data row2 col4" >57.59%</td>
#     </tr>
#     <tr>
#       <th id="T_008c6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_008c6_row3_col0" class="data row3 col0" >RS</td>
#       <td id="T_008c6_row3_col1" class="data row3 col1" >361</td>
#       <td id="T_008c6_row3_col2" class="data row3 col2" >7.90%</td>
#       <td id="T_008c6_row3_col3" class="data row3 col3" >2,991</td>
#       <td id="T_008c6_row3_col4" class="data row3 col4" >65.49%</td>
#     </tr>
#     <tr>
#       <th id="T_008c6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_008c6_row4_col0" class="data row4 col0" >PR</td>
#       <td id="T_008c6_row4_col1" class="data row4 col1" >201</td>
#       <td id="T_008c6_row4_col2" class="data row4 col2" >4.40%</td>
#       <td id="T_008c6_row4_col3" class="data row4 col3" >3,192</td>
#       <td id="T_008c6_row4_col4" class="data row4 col4" >69.89%</td>
#     </tr>
#     <tr>
#       <th id="T_008c6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_008c6_row5_col0" class="data row5 col0" >GO</td>
#       <td id="T_008c6_row5_col1" class="data row5 col1" >172</td>
#       <td id="T_008c6_row5_col2" class="data row5 col2" >3.77%</td>
#       <td id="T_008c6_row5_col3" class="data row5 col3" >3,364</td>
#       <td id="T_008c6_row5_col4" class="data row5 col4" >73.66%</td>
#     </tr>
#     <tr>
#       <th id="T_008c6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_008c6_row6_col0" class="data row6 col0" >BA</td>
#       <td id="T_008c6_row6_col1" class="data row6 col1" >160</td>
#       <td id="T_008c6_row6_col2" class="data row6 col2" >3.50%</td>
#       <td id="T_008c6_row6_col3" class="data row6 col3" >3,524</td>
#       <td id="T_008c6_row6_col4" class="data row6 col4" >77.16%</td>
#     </tr>
#     <tr>
#       <th id="T_008c6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_008c6_row7_col0" class="data row7 col0" >SC</td>
#       <td id="T_008c6_row7_col1" class="data row7 col1" >126</td>
#       <td id="T_008c6_row7_col2" class="data row7 col2" >2.76%</td>
#       <td id="T_008c6_row7_col3" class="data row7 col3" >3,650</td>
#       <td id="T_008c6_row7_col4" class="data row7 col4" >79.92%</td>
#     </tr>
#     <tr>
#       <th id="T_008c6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_008c6_row8_col0" class="data row8 col0" >PA</td>
#       <td id="T_008c6_row8_col1" class="data row8 col1" >123</td>
#       <td id="T_008c6_row8_col2" class="data row8 col2" >2.69%</td>
#       <td id="T_008c6_row8_col3" class="data row8 col3" >3,773</td>
#       <td id="T_008c6_row8_col4" class="data row8 col4" >82.61%</td>
#     </tr>
#     <tr>
#       <th id="T_008c6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_008c6_row9_col0" class="data row9 col0" >MS</td>
#       <td id="T_008c6_row9_col1" class="data row9 col1" >102</td>
#       <td id="T_008c6_row9_col2" class="data row9 col2" >2.23%</td>
#       <td id="T_008c6_row9_col3" class="data row9 col3" >3,875</td>
#       <td id="T_008c6_row9_col4" class="data row9 col4" >84.85%</td>
#     </tr>
#     <tr>
#       <th id="T_008c6_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_008c6_row10_col0" class="data row10 col0" >MT</td>
#       <td id="T_008c6_row10_col1" class="data row10 col1" >92</td>
#       <td id="T_008c6_row10_col2" class="data row10 col2" >2.01%</td>
#       <td id="T_008c6_row10_col3" class="data row10 col3" >3,967</td>
#       <td id="T_008c6_row10_col4" class="data row10 col4" >86.86%</td>
#     </tr>
#     <tr>
#       <th id="T_008c6_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_008c6_row11_col0" class="data row11 col0" >RN</td>
#       <td id="T_008c6_row11_col1" class="data row11 col1" >80</td>
#       <td id="T_008c6_row11_col2" class="data row11 col2" >1.75%</td>
#       <td id="T_008c6_row11_col3" class="data row11 col3" >4,047</td>
#       <td id="T_008c6_row11_col4" class="data row11 col4" >88.61%</td>
#     </tr>
#     <tr>
#       <th id="T_008c6_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_008c6_row12_col0" class="data row12 col0" >PB</td>
#       <td id="T_008c6_row12_col1" class="data row12 col1" >72</td>
#       <td id="T_008c6_row12_col2" class="data row12 col2" >1.58%</td>
#       <td id="T_008c6_row12_col3" class="data row12 col3" >4,119</td>
#       <td id="T_008c6_row12_col4" class="data row12 col4" >90.19%</td>
#     </tr>
#     <tr>
#       <th id="T_008c6_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_008c6_row13_col0" class="data row13 col0" >DF</td>
#       <td id="T_008c6_row13_col1" class="data row13 col1" >62</td>
#       <td id="T_008c6_row13_col2" class="data row13 col2" >1.36%</td>
#       <td id="T_008c6_row13_col3" class="data row13 col3" >4,181</td>
#       <td id="T_008c6_row13_col4" class="data row13 col4" >91.55%</td>
#     </tr>
#     <tr>
#       <th id="T_008c6_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_008c6_row14_col0" class="data row14 col0" >ES</td>
#       <td id="T_008c6_row14_col1" class="data row14 col1" >59</td>
#       <td id="T_008c6_row14_col2" class="data row14 col2" >1.29%</td>
#       <td id="T_008c6_row14_col3" class="data row14 col3" >4,240</td>
#       <td id="T_008c6_row14_col4" class="data row14 col4" >92.84%</td>
#     </tr>
#     <tr>
#       <th id="T_008c6_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_008c6_row15_col0" class="data row15 col0" >PE</td>
#       <td id="T_008c6_row15_col1" class="data row15 col1" >48</td>
#       <td id="T_008c6_row15_col2" class="data row15 col2" >1.05%</td>
#       <td id="T_008c6_row15_col3" class="data row15 col3" >4,288</td>
#       <td id="T_008c6_row15_col4" class="data row15 col4" >93.89%</td>
#     </tr>
#     <tr>
#       <th id="T_008c6_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_008c6_row16_col0" class="data row16 col0" >TO</td>
#       <td id="T_008c6_row16_col1" class="data row16 col1" >47</td>
#       <td id="T_008c6_row16_col2" class="data row16 col2" >1.03%</td>
#       <td id="T_008c6_row16_col3" class="data row16 col3" >4,335</td>
#       <td id="T_008c6_row16_col4" class="data row16 col4" >94.92%</td>
#     </tr>
#     <tr>
#       <th i

# %%
# Total de obitos por municipio (top 10)
df[df['data'] == '2024-09-14'].stb.freq(['municipio'],value='obitosAcumulado',thresh = 22,style=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_1c03a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1c03a_level0_col0" class="col_heading level0 col0" >municipio</th>
#       <th id="T_1c03a_level0_col1" class="col_heading level0 col1" >obitosAcumulado</th>
#       <th id="T_1c03a_level0_col2" class="col_heading level0 col2" >percent</th>
#       <th id="T_1c03a_level0_col3" class="col_heading level0 col3" >cumulative_obitosAcumulado</th>
#       <th id="T_1c03a_level0_col4" class="col_heading level0 col4" >cumulative_percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1c03a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1c03a_row0_col0" class="data row0 col0" >São Paulo</td>
#       <td id="T_1c03a_row0_col1" class="data row0 col1" >46,024</td>
#       <td id="T_1c03a_row0_col2" class="data row0 col2" >6.46%</td>
#       <td id="T_1c03a_row0_col3" class="data row0 col3" >46,024</td>
#       <td id="T_1c03a_row0_col4" class="data row0 col4" >6.46%</td>
#     </tr>
#     <tr>
#       <th id="T_1c03a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1c03a_row1_col0" class="data row1 col0" >Rio de Janeiro</td>
#       <td id="T_1c03a_row1_col1" class="data row1 col1" >38,661</td>
#       <td id="T_1c03a_row1_col2" class="data row1 col2" >5.43%</td>
#       <td id="T_1c03a_row1_col3" class="data row1 col3" >84,685</td>
#       <td id="T_1c03a_row1_col4" class="data row1 col4" >11.89%</td>
#     </tr>
#     <tr>
#       <th id="T_1c03a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1c03a_row2_col0" class="data row2 col0" >Brasília</td>
#       <td id="T_1c03a_row2_col1" class="data row2 col1" >12,014</td>
#       <td id="T_1c03a_row2_col2" class="data row2 col2" >1.69%</td>
#       <td id="T_1c03a_row2_col3" class="data row2 col3" >96,699</td>
#       <td id="T_1c03a_row2_col4" class="data row2 col4" >13.58%</td>
#     </tr>
#     <tr>
#       <th id="T_1c03a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1c03a_row3_col0" class="data row3 col0" >Fortaleza</td>
#       <td id="T_1c03a_row3_col1" class="data row3 col1" >11,818</td>
#       <td id="T_1c03a_row3_col2" class="data row3 col2" >1.66%</td>
#       <td id="T_1c03a_row3_col3" class="data row3 col3" >108,517</td>
#       <td id="T_1c03a_row3_col4" class="data row3 col4" >15.24%</td>
#     </tr>
#     <tr>
#       <th id="T_1c03a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1c03a_row4_col0" class="data row4 col0" >Manaus</td>
#       <td id="T_1c03a_row4_col1" class="data row4 col1" >9,966</td>
#       <td id="T_1c03a_row4_col2" class="data row4 col2" >1.40%</td>
#       <td id="T_1c03a_row4_col3" class="data row4 col3" >118,483</td>
#       <td id="T_1c03a_row4_col4" class="data row4 col4" >16.63%</td>
#     </tr>
#     <tr>
#       <th id="T_1c03a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1c03a_row5_col0" class="data row5 col0" >Salvador</td>
#       <td id="T_1c03a_row5_col1" class="data row5 col1" >9,222</td>
#       <td id="T_1c03a_row5_col2" class="data row5 col2" >1.29%</td>
#       <td id="T_1c03a_row5_col3" class="data row5 col3" >127,705</td>
#       <td id="T_1c03a_row5_col4" class="data row5 col4" >17.93%</td>
#     </tr>
#     <tr>
#       <th id="T_1c03a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1c03a_row6_col0" class="data row6 col0" >Curitiba</td>
#       <td id="T_1c03a_row6_col1" class="data row6 col1" >8,929</td>
#       <td id="T_1c03a_row6_col2" class="data row6 col2" >1.25%</td>
#       <td id="T_1c03a_row6_col3" class="data row6 col3" >136,634</td>
#       <td id="T_1c03a_row6_col4" class="data row6 col4" >19.18%</td>
#     </tr>
#     <tr>
#       <th id="T_1c03a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1c03a_row7_col0" class="data row7 col0" >Belo Horizonte</td>
#       <td id="T_1c03a_row7_col1" class="data row7 col1" >8,671</td>
#       <td id="T_1c03a_row7_col2" class="data row7 col2" >1.22%</td>
#       <td id="T_1c03a_row7_col3" class="data row7 col3" >145,305</td>
#       <td id="T_1c03a_row7_col4" class="data row7 col4" >20.40%</td>
#     </tr>
#     <tr>
#       <th id="T_1c03a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1c03a_row8_col0" class="data row8 col0" >Goiânia</td>
#       <td id="T_1c03a_row8_col1" class="data row8 col1" >8,167</td>
#       <td id="T_1c03a_row8_col2" class="data row8 col2" >1.15%</td>
#       <td id="T_1c03a_row8_col3" class="data row8 col3" >153,472</td>
#       <td id="T_1c03a_row8_col4" class="data row8 col4" >21.55%</td>
#     </tr>
#     <tr>
#       <th id="T_1c03a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1c03a_row9_col0" class="data row9 col0" >others</td>
#       <td id="T_1c03a_row9_col1" class="data row9 col1" >558,815</td>
#       <td id="T_1c03a_row9_col2" class="data row9 col2" >78.45%</td>
#       <td id="T_1c03a_row9_col3" class="data row9 col3" >712,287</td>
#       <td id="T_1c03a_row9_col4" class="data row9 col4" >100.00%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## **Com base nas informações obtidas, formular hipóteses:**

# %% [markdown]
# <img src='https://caelum-online-public.s3.amazonaws.com/1229-estatistica-parte3/01/img003.png' width=70%>

# %% [markdown]
# > ![Níveis de Confiança e significância](https://caelum-online-public.s3.amazonaws.com/1229-estatistica-parte3/01/img001.png)

# %% [markdown]
# <img src='https://caelum-online-public.s3.amazonaws.com/1229-estatistica-parte3/01/img013.png' width=90%>

# %% [markdown]
# ### 1a Hipótese: a média de óbitos na região sudeste é superior à média amostral
# #### Existe evidência suficiente no nível α = 0.05 para concluir que a média de óbitos da região sudeste é superior à média de todas as regiões?

# %% [markdown]
# ### **Passo 1** - formulação das hipóteses $H_0$ e $H_1$
#
# #### <font color='red'>Lembre-se, a hipótese nula sempre contém a alegação de igualdade</font>

# %%
dados_sem_sudeste = df[(df['data'] == '2024-09-14') & (df['regiao'] != "Sudeste")]
dados_sudeste = df[(df['data'] == '2024-09-14') & (df['regiao'] == "Sudeste")]

dados_sudeste.head()
# Out:
#              data   regiao estado            municipio  populacaoTCU2019  \
# 173735 2024-09-14  Sudeste     MG  Abadia dos Dourados            6989.0
# 173811 2024-09-14  Sudeste     MG               Abaeté           23237.0
# 173887 2024-09-14  Sudeste     MG           Abre Campo           13454.0
# 173963 2024-09-14  Sudeste     MG              Acaiaca            3994.0
# 174039 2024-09-14  Sudeste     MG              Açucena            9470.0
#
#         obitosAcumulado  obitosNovos   ano        mes  percentual_obitos
# 173735               21            0  2024  September           0.300472
# 173811               50            0  2024  September           0.215174
# 173887               19            0  2024  September           0.141222
# 173963               12            0  2024  September           0.300451
# 174039               39            0  2024  September           0.411827

# %%
dados_sem_sudeste.head()
# Out:
#            data regiao estado              municipio  populacaoTCU2019  \
# 2279 2024-09-14  Norte     RO  Alta Floresta D'Oeste           22945.0
# 2355 2024-09-14  Norte     RO              Ariquemes          107863.0
# 2431 2024-09-14  Norte     RO                 Cabixi            5312.0
# 2507 2024-09-14  Norte     RO                 Cacoal           85359.0
# 2583 2024-09-14  Norte     RO             Cerejeiras           16323.0
#
#       obitosAcumulado  obitosNovos   ano        mes  percentual_obitos
# 2279               85            0  2024  September           0.370451
# 2355              570            0  2024  September           0.528448
# 2431               23            0  2024  September           0.432982
# 2507              364            0  2024  September           0.426434
# 2583               74            0  2024  September           0.453348

# %%
dados_sem_sudeste.shape[0]
# Out:
# 3902

# %% [markdown]
# ### **Passo 2** - escolha da distribuição amostral adequada

# %% [markdown]
# ### O tamanho da amostra é maior que 30?
# #### Resp.: Sim
#
# ### O desvio padrão populacional é conhecido?
# #### Resp.: Não

# %% [markdown]
# ### **Passo 3** - fixação da significância do teste ($\alpha$)

# %%
media_amostral = dados_sudeste['obitosAcumulado'].mean()
media = dados_sem_sudeste['obitosAcumulado'].mean()
desvio_padrao_amostral = dados_sudeste['obitosAcumulado'].std()


significancia = 0.05
confianca = 1 - significancia
n = df[(df['regiao'] == "Sudeste") & (df['data'] == '2024-09-14')].shape[0]
print(media, media_amostral, desvio_padrao_amostral,n)
# Out:
# 94.46796514607894 206.03896882494004 1541.097248240522 1668

# %% [markdown]
# ### **Passo 4** - cálculo da estatística-teste e verificação desse valor com as áreas de aceitação e rejeição do teste
#
# # $$z = \frac{\bar{x} - \mu_0}{\frac{s}{\sqrt{n}}}$$

# %% [markdown]
# ### Critério do $p-valor$
# > ### Rejeitar $H_0$ se o valor $p\leq\alpha$

# %%
from scipy.stats import norm
z = (media_amostral - media)/(desvio_padrao_amostral/np.sqrt(n))
z_alpha = norm.ppf(confianca)
p_valor = 2 * norm.sf(abs(z))
print(p_valor,n)
print("Z: ", z)
print("Z alpha: ",-z_alpha)
print("Z >= Z_alpha? ", (z>=z_alpha))
print("P_valor < Significancia? ", p_valor < significancia)
print("Hipotese nula rejeitada. A média de óbitos da região sudeste É superior a média de óbitos do resto do país")
# Out:
# 0.0031086773445038415 1668
# Z:  2.9567820846754707
# Z alpha:  -1.6448536269514722
# Z >= Z_alpha?  True
# P_valor < Significancia?  True
# Hipotese nula rejeitada. A média de óbitos da região sudeste É superior a média de óbitos do resto do país

# %%
from statsmodels.stats.weightstats import ztest
z, pvalor= ztest(dados_sudeste['obitosAcumulado'],value = media,alternative='larger')

# %%
pvalor < significancia
# Out:
# np.True_

# %% [markdown]
# ### 2a hipótese: O número de mortes no inverno de 2020 foi maior que nas outras estações
# #### Existe evidência suficiente no nível α = 0.05 para concluir que o número de óbitos entre 20 de junho e 22 de setembro de 2020 correspondem a 25% ou mais dos óbitos do ano?

# %%
comeco_inverno = df[(df['data'] == '2020-06-20')]
fim_inverno = df[(df['data'] == '2020-09-22')]

comeco_inverno = comeco_inverno.reset_index()['obitosAcumulado']
fim_inverno = fim_inverno.reset_index()['obitosAcumulado']

mortes_durante_inverno = fim_inverno.sum() - comeco_inverno.sum()

# %%
total_ano = df[(df['data'] == '2020-12-31')]
mortes_total = total_ano.reset_index()['obitosAcumulado']

p_observada = mortes_durante_inverno / mortes_total.sum()
p_observada
# Out:
# np.float64(0.45223270246388425)

# %%
from statsmodels.stats.proportion import proportions_ztest

# Definir o tamanho da amostra
n = fim_inverno.shape[0] #número de amostra

# Definir a proporção esperada (p0)
# Considerando que tem 4 estações no ano, o esperado seria que 1/4 das mortes ocorresse em cada estação, portanto:
p0 = 0.25

# Realizar o teste de proporção
z = (p_observada - p0)/np.sqrt((p_observada*(1-p_observada))/n)
z
# Out:
# np.float64(30.32494001330274)

# %%
significancia = 0.05
confianca = 1 - significancia/2

# %%
from scipy.stats import norm
z_alpha = norm.ppf(confianca)
p_valor = 2 * norm.sf(abs(z))
print(n)
print("Z: ", z)
print("Z alpha: ",z_alpha)
print("Z >= Z_alpha? ", z <=- z_alpha or z>= z_alpha)
print("P_valor < Significancia? ", p_valor < significancia)
print("Hipotese nula rejeitada. Há evidência que houveram mais mortes no inverno de 2020 do que em outras estações")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 from scipy.stats import norm
# ----> 2 z_alpha = norm.ppf(confianca)
#       3 p_valor = 2 * norm.sf(abs(z))
#       4 print(n)
#
# NameError: name 'confianca' is not defined

# %%
# Agregar os dados por município
municipio_data = df.groupby('municipio').agg(
    populacao_total=('populacaoTCU2019', 'sum'),
    obitos_acumulados=('obitosAcumulado', 'sum')
).reset_index()

# Extrair as variáveis
x = municipio_data['populacao_total']
y = municipio_data['obitos_acumulados']

# Número de municípios
n = 5570

# Cálculos necessários para a fórmula
sum_x = x.sum()
sum_y = y.sum()
sum_xy = (x * y).sum()
sum_x2 = (x ** 2).sum()
sum_y2 = (y ** 2).sum()

# Aplicando a fórmula de Pearson
numerador = n * sum_xy - (sum_x * sum_y)
denominador = ((n * sum_x2 - sum_x**2) * (n * sum_y2 - sum_y**2))**0.5

correlacao_pearson = numerador / denominador

z = (correlacao_pearson * np.sqrt(n-2))/np.sqrt(1-(correlacao_pearson**2))
p_valor = 2 * (1 - norm.cdf(abs(z)))
print(z,p_valor,n)

print(f"Correlação de Pearson: {correlacao_pearson:.4f}")
print("Há uma forte correlação entre a população de um município e o número de óbitos")
# Out:
# 339.6251825203236 0.0 5570
# Correlação de Pearson: 0.9767
# Há uma forte correlação entre a população de um município e o número de óbitos

# %%
df[df['data'] == '2024-09-14'].stb.freq(['municipio'],value='obitosAcumulado',thresh = 22,style=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_83322">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_83322_level0_col0" class="col_heading level0 col0" >municipio</th>
#       <th id="T_83322_level0_col1" class="col_heading level0 col1" >obitosAcumulado</th>
#       <th id="T_83322_level0_col2" class="col_heading level0 col2" >percent</th>
#       <th id="T_83322_level0_col3" class="col_heading level0 col3" >cumulative_obitosAcumulado</th>
#       <th id="T_83322_level0_col4" class="col_heading level0 col4" >cumulative_percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83322_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_83322_row0_col0" class="data row0 col0" >São Paulo</td>
#       <td id="T_83322_row0_col1" class="data row0 col1" >46,024</td>
#       <td id="T_83322_row0_col2" class="data row0 col2" >6.46%</td>
#       <td id="T_83322_row0_col3" class="data row0 col3" >46,024</td>
#       <td id="T_83322_row0_col4" class="data row0 col4" >6.46%</td>
#     </tr>
#     <tr>
#       <th id="T_83322_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_83322_row1_col0" class="data row1 col0" >Rio de Janeiro</td>
#       <td id="T_83322_row1_col1" class="data row1 col1" >38,661</td>
#       <td id="T_83322_row1_col2" class="data row1 col2" >5.43%</td>
#       <td id="T_83322_row1_col3" class="data row1 col3" >84,685</td>
#       <td id="T_83322_row1_col4" class="data row1 col4" >11.89%</td>
#     </tr>
#     <tr>
#       <th id="T_83322_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_83322_row2_col0" class="data row2 col0" >Brasília</td>
#       <td id="T_83322_row2_col1" class="data row2 col1" >12,014</td>
#       <td id="T_83322_row2_col2" class="data row2 col2" >1.69%</td>
#       <td id="T_83322_row2_col3" class="data row2 col3" >96,699</td>
#       <td id="T_83322_row2_col4" class="data row2 col4" >13.58%</td>
#     </tr>
#     <tr>
#       <th id="T_83322_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_83322_row3_col0" class="data row3 col0" >Fortaleza</td>
#       <td id="T_83322_row3_col1" class="data row3 col1" >11,818</td>
#       <td id="T_83322_row3_col2" class="data row3 col2" >1.66%</td>
#       <td id="T_83322_row3_col3" class="data row3 col3" >108,517</td>
#       <td id="T_83322_row3_col4" class="data row3 col4" >15.24%</td>
#     </tr>
#     <tr>
#       <th id="T_83322_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_83322_row4_col0" class="data row4 col0" >Manaus</td>
#       <td id="T_83322_row4_col1" class="data row4 col1" >9,966</td>
#       <td id="T_83322_row4_col2" class="data row4 col2" >1.40%</td>
#       <td id="T_83322_row4_col3" class="data row4 col3" >118,483</td>
#       <td id="T_83322_row4_col4" class="data row4 col4" >16.63%</td>
#     </tr>
#     <tr>
#       <th id="T_83322_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_83322_row5_col0" class="data row5 col0" >Salvador</td>
#       <td id="T_83322_row5_col1" class="data row5 col1" >9,222</td>
#       <td id="T_83322_row5_col2" class="data row5 col2" >1.29%</td>
#       <td id="T_83322_row5_col3" class="data row5 col3" >127,705</td>
#       <td id="T_83322_row5_col4" class="data row5 col4" >17.93%</td>
#     </tr>
#     <tr>
#       <th id="T_83322_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_83322_row6_col0" class="data row6 col0" >Curitiba</td>
#       <td id="T_83322_row6_col1" class="data row6 col1" >8,929</td>
#       <td id="T_83322_row6_col2" class="data row6 col2" >1.25%</td>
#       <td id="T_83322_row6_col3" class="data row6 col3" >136,634</td>
#       <td id="T_83322_row6_col4" class="data row6 col4" >19.18%</td>
#     </tr>
#     <tr>
#       <th id="T_83322_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_83322_row7_col0" class="data row7 col0" >Belo Horizonte</td>
#       <td id="T_83322_row7_col1" class="data row7 col1" >8,671</td>
#       <td id="T_83322_row7_col2" class="data row7 col2" >1.22%</td>
#       <td id="T_83322_row7_col3" class="data row7 col3" >145,305</td>
#       <td id="T_83322_row7_col4" class="data row7 col4" >20.40%</td>
#     </tr>
#     <tr>
#       <th id="T_83322_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_83322_row8_col0" class="data row8 col0" >Goiânia</td>
#       <td id="T_83322_row8_col1" class="data row8 col1" >8,167</td>
#       <td id="T_83322_row8_col2" class="data row8 col2" >1.15%</td>
#       <td id="T_83322_row8_col3" class="data row8 col3" >153,472</td>
#       <td id="T_83322_row8_col4" class="data row8 col4" >21.55%</td>
#     </tr>
#     <tr>
#       <th id="T_83322_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_83322_row9_col0" class="data row9 col0" >others</td>
#       <td id="T_83322_row9_col1" class="data row9 col1" >558,815</td>
#       <td id="T_83322_row9_col2" class="data row9 col2" >78.45%</td>
#       <td id="T_83322_row9_col3" class="data row9 col3" >712,287</td>
#       <td id="T_83322_row9_col4" class="data row9 col4" >100.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
df[df['data'] == '2024-09-14'].stb.freq(['municipio'],value='populacaoTCU2019',thresh = 22,style=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_10f41">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_10f41_level0_col0" class="col_heading level0 col0" >municipio</th>
#       <th id="T_10f41_level0_col1" class="col_heading level0 col1" >populacaoTCU2019</th>
#       <th id="T_10f41_level0_col2" class="col_heading level0 col2" >percent</th>
#       <th id="T_10f41_level0_col3" class="col_heading level0 col3" >cumulative_populacaoTCU2019</th>
#       <th id="T_10f41_level0_col4" class="col_heading level0 col4" >cumulative_percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_10f41_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_10f41_row0_col0" class="data row0 col0" >São Paulo</td>
#       <td id="T_10f41_row0_col1" class="data row0 col1" >12,252,023</td>
#       <td id="T_10f41_row0_col2" class="data row0 col2" >5.83%</td>
#       <td id="T_10f41_row0_col3" class="data row0 col3" >12,252,023</td>
#       <td id="T_10f41_row0_col4" class="data row0 col4" >5.83%</td>
#     </tr>
#     <tr>
#       <th id="T_10f41_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_10f41_row1_col0" class="data row1 col0" >Rio de Janeiro</td>
#       <td id="T_10f41_row1_col1" class="data row1 col1" >6,718,903</td>
#       <td id="T_10f41_row1_col2" class="data row1 col2" >3.20%</td>
#       <td id="T_10f41_row1_col3" class="data row1 col3" >18,970,926</td>
#       <td id="T_10f41_row1_col4" class="data row1 col4" >9.03%</td>
#     </tr>
#     <tr>
#       <th id="T_10f41_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_10f41_row2_col0" class="data row2 col0" >Brasília</td>
#       <td id="T_10f41_row2_col1" class="data row2 col1" >3,015,268</td>
#       <td id="T_10f41_row2_col2" class="data row2 col2" >1.43%</td>
#       <td id="T_10f41_row2_col3" class="data row2 col3" >21,986,194</td>
#       <td id="T_10f41_row2_col4" class="data row2 col4" >10.46%</td>
#     </tr>
#     <tr>
#       <th id="T_10f41_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_10f41_row3_col0" class="data row3 col0" >Salvador</td>
#       <td id="T_10f41_row3_col1" class="data row3 col1" >2,872,347</td>
#       <td id="T_10f41_row3_col2" class="data row3 col2" >1.37%</td>
#       <td id="T_10f41_row3_col3" class="data row3 col3" >24,858,541</td>
#       <td id="T_10f41_row3_col4" class="data row3 col4" >11.83%</td>
#     </tr>
#     <tr>
#       <th id="T_10f41_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_10f41_row4_col0" class="data row4 col0" >Fortaleza</td>
#       <td id="T_10f41_row4_col1" class="data row4 col1" >2,669,342</td>
#       <td id="T_10f41_row4_col2" class="data row4 col2" >1.27%</td>
#       <td id="T_10f41_row4_col3" class="data row4 col3" >27,527,883</td>
#       <td id="T_10f41_row4_col4" class="data row4 col4" >13.10%</td>
#     </tr>
#     <tr>
#       <th id="T_10f41_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_10f41_row5_col0" class="data row5 col0" >Belo Horizonte</td>
#       <td id="T_10f41_row5_col1" class="data row5 col1" >2,512,070</td>
#       <td id="T_10f41_row5_col2" class="data row5 col2" >1.20%</td>
#       <td id="T_10f41_row5_col3" class="data row5 col3" >30,039,953</td>
#       <td id="T_10f41_row5_col4" class="data row5 col4" >14.29%</td>
#     </tr>
#     <tr>
#       <th id="T_10f41_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_10f41_row6_col0" class="data row6 col0" >Manaus</td>
#       <td id="T_10f41_row6_col1" class="data row6 col1" >2,182,763</td>
#       <td id="T_10f41_row6_col2" class="data row6 col2" >1.04%</td>
#       <td id="T_10f41_row6_col3" class="data row6 col3" >32,222,716</td>
#       <td id="T_10f41_row6_col4" class="data row6 col4" >15.33%</td>
#     </tr>
#     <tr>
#       <th id="T_10f41_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_10f41_row7_col0" class="data row7 col0" >Curitiba</td>
#       <td id="T_10f41_row7_col1" class="data row7 col1" >1,933,105</td>
#       <td id="T_10f41_row7_col2" class="data row7 col2" >0.92%</td>
#       <td id="T_10f41_row7_col3" class="data row7 col3" >34,155,821</td>
#       <td id="T_10f41_row7_col4" class="data row7 col4" >16.25%</td>
#     </tr>
#     <tr>
#       <th id="T_10f41_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_10f41_row8_col0" class="data row8 col0" >Recife</td>
#       <td id="T_10f41_row8_col1" class="data row8 col1" >1,645,727</td>
#       <td id="T_10f41_row8_col2" class="data row8 col2" >0.78%</td>
#       <td id="T_10f41_row8_col3" class="data row8 col3" >35,801,548</td>
#       <td id="T_10f41_row8_col4" class="data row8 col4" >17.04%</td>
#     </tr>
#     <tr>
#       <th id="T_10f41_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_10f41_row9_col0" class="data row9 col0" >Goiânia</td>
#       <td id="T_10f41_row9_col1" class="data row9 col1" >1,516,113</td>
#       <td id="T_10f41_row9_col2" class="data row9 col2" >0.72%</td>
#       <td id="T_10f41_row9_col3" class="data row9 col3" >37,317,661</td>
#       <td id="T_10f41_row9_col4" class="data row9 col4" >17.76%</td>
#     </tr>
#     <tr>
#       <th id="T_10f41_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_10f41_row10_col0" class="data row10 col0" >Belém</td>
#       <td id="T_10f41_row10_col1" class="data row10 col1" >1,514,765</td>
#       <td id="T_10f41_row10_col2" class="data row10 col2" >0.72%</td>
#       <td id="T_10f41_row10_col3" class="data row10 col3" >38,832,426</td>
#       <td id="T_10f41_row10_col4" class="data row10 col4" >18.48%</td>
#     </tr>
#     <tr>
#       <th id="T_10f41_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_10f41_row11_col0" class="data row11 col0" >Porto Alegre</td>
#       <td id="T_10f41_row11_col1" class="data row11 col1" >1,483,771</td>
#       <td id="T_10f41_row11_col2" class="data row11 col2" >0.71%</td>
#       <td id="T_10f41_row11_col3" class="data row11 col3" >40,316,197</td>
#       <td id="T_10f41_row11_col4" class="data row11 col4" >19.18%</td>
#     </tr>
#     <tr>
#       <th id="T_10f41_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_10f41_row12_col0" class="data row12 col0" >Guarulhos</td>
#       <td id="T_10f41_row12_col1" class="data row12 col1" >1,379,182</td>
#       <td id="T_10f41_row12_col2" class="data row12 col2" >0.66%</td>
#       <td id="T_10f41_row12_col3" class="data row12 col3" >41,695,379</td>
#       <td id="T_10f41_row12_col4" class="data row12 col4" >19.84%</td>
#     </tr>
#     <tr>
#       <th id="T_10f41_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_10f41_row13_col0" class="data row13 col0" >Campinas</td>
#       <td id="T_10f41_row13_col1" class="data row13 col1" >1,204,073</td>
#       <td id="T_10f41_row13_col2" class="data row13 col2" >0.57%</td>
#       <td id="T_10f41_row13_col3" class="data row13 col3" >42,899,452</td>
#       <td id="T_10f41_row13_col4" class="data row13 col4" >20.41%</td>
#     </tr>
#     <tr>
#       <th id="T_10f41_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_10f41_row14_col0" class="data row14 col0" >São Luís</td>
#       <td id="T_10f41_row14_col1" class="data row14 col1" >1,101,884</td>
#       <td id="T_10f41_row14_col2" class="data row14 col2" >0.52%</td>
#       <td id="T_10f41_row14_col3" class="data row14 col3" >44,001,336</td>
#       <td id="T_10f41_row14_col4" class="data row14 col4" >20.94%</td>
#     </tr>
#     <tr>
#       <th id="T_10f41_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_10f41_row15_col0" class="data row15 col0" >São Gonçalo</td>
#       <td id="T_10f41_row15_col1" class="data row15 col1" >1,084,839</td>
#       <td id="T_10f41_row15_col2" class="data row15 col2" >0.52%</td>
#       <td id="T_10f41_row15_col3" class="data row15 col3" >45,086,175</td>
#       <td id="T_10f41_row15_col4" class="data row15 col4" >21.45%</td>
#     </tr>
#     <tr>
#       <th id="T_10f41_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_10f41_row16_col0" class="data row16 col0" >Maceió</td>
